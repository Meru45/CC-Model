# %%
#!pip install --pre deepchem

import deepchem as dc
dc.__version__
# Out:
# '2.7.2.dev'

# %%
import numpy as np
import matplotlib.pyplot as plt

from deepchem.data import NumpyDataset
from deepchem.models.torch_models import CNN

# %%
import torch
dummy_1 = np.ones((13780))
dummy_1
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
data_location = 'data/malaria.zip'
loader = dc.data.ImageLoader()
loader.create_dataset(data_location)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 2
#       1 data_location = 'data/malaria.zip'
# ----> 2 malaria_dataset = dc.data.ImageDataset([data_location], dummy_1)
#
# File ~/anaconda3/envs/cc/lib/python3.10/site-packages/deepchem/data/datasets.py:2752, in ImageDataset.__init__(self, X, y, w, ids)
#    2750 if y is None:
#    2751     y = np.zeros((n_samples,))
# -> 2752 self._X_shape = self._find_array_shape(X)
#    2753 self._y_shape = self._find_array_shape(y)
#    2754 if w is None:
#
# File ~/anaconda3/envs/cc/lib/python3.10/site-packages/deepchem/data/datasets.py:2779, in ImageDataset._find_array_shape(self, array)
#    2777 if isinstance(array, np.ndarray):
#    2778     return array.shape
# -> 2779 image_shape = load_image_files([array[0]]).shape[1:]
#    2780 return tuple(np.concatenate([[len(array)], image_shape]))
#
# File ~/anaconda3/envs/cc/lib/python3.10/site-packages/deepchem/utils/data_utils.py:213, in load_image_files(input_files)
#     211         images.append(imarray)
#     212     else:
# --> 213         raise ValueError("Unsupported image filetype for %s" % input_file)
#     214 # dtype=object allows for arrays(images here) of arbitrary size
#     215 try:
#
# ValueError: Unsupported image filetype for data/malaria.zip

# %%
bbbc2_dataset = dc.molnet.load_bbbc002(splitter='random')
tasks, dataset, transforms = bbbc2_dataset
train, val, test = dataset

train_x, train_y, train_w, train_ids = train.X, train.y, train.w, train.ids
val_x, val_y, val_w, val_ids = val.X, val.y, val.w, val.ids
test_x, test_y, test_w, test_ids = test.X, test.y, test.w, test.ids

# %%
print(f"Shape of train data: {train_x.shape}")
print(f"Shape of train labels: {train_y.shape}")
# Out:
# Shape of train data: (40, 512, 512)
# Shape of train labels: (40,)

# %%
plt.imshow(new)

# %%
X = []
y = []
count = 0

# %%
data_size = len(dataset)
for i in range(count, data_size):
    X.append(dataset[count])
    y.append(dataset[count])
    #X.append(i[0])
    #y.append(i[1])
    count += 1
    if count % 100 == 0:
        print(count)
    if count == 10000:
        break

# %%
from xgboost import XGBClassifier
# read data
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
data = load_iris()
X_train, X_test, y_train, y_test = train_test_split(dataset['data'], dataset['target'], test_size=.2)
# create model instance
bst = XGBClassifier(n_estimators=2, max_depth=2, learning_rate=1, objective='binary:logistic')
# fit model
bst.fit(X_train, y_train)
# make predictions
preds = bst.predict(X_test)
preds, y_test
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 6
#       4 from sklearn.model_selection import train_test_split
#       5 data = load_iris()
# ----> 6 X_train, X_test, y_train, y_test = train_test_split(dataset['data'], dataset['target'], test_size=.2)
#       7 # create model instance
#       8 bst = XGBClassifier(n_estimators=2, max_depth=2, learning_rate=1, objective='binary:logistic')
#
# File ~/anaconda3/envs/cc/lib/python3.10/site-packages/torchvision/datasets/folder.py:228, in DatasetFolder.__getitem__(self, index)
#     220 def __getitem__(self, index: int) -> Tuple[Any, Any]:
#     221     """
#     222     Args:
#     223         index (int): Index
#    (...)
#     226         tuple: (sample, target) where target is class_index of the target class.
#     227     """
# --> 228     path, target = self.samples[index]
#     229     sample = self.loader(path)
#     230     if self.transform is not None:
#
# TypeError: list indices must be integers or slices, not str

# %%
from xgboost import XGBClassifier
# read data
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
data = load_iris()
X_train, X_test, y_train, y_test = train_test_split(data['data'], data['target'], test_size=.2)
# create model instance
bst = XGBClassifier(n_estimators=2, max_depth=2, learning_rate=1, objective='binary:logistic')
# fit model
bst.fit(X_train, y_train)
# make predictions
preds = bst.predict(X_test)
preds, y_test
# Out:
# (array([1, 0, 1, 1, 1, 1, 1, 1, 0, 2, 1, 2, 1, 0, 1, 2, 1, 1, 1, 2, 0, 1,
#         0, 0, 2, 2, 0, 1, 2, 2]),
#  array([1, 0, 1, 1, 2, 1, 1, 1, 0, 2, 1, 2, 2, 0, 2, 2, 1, 1, 1, 2, 0, 1,
#         0, 0, 2, 2, 0, 1, 2, 2]))

# %%
import deepchem as dc

from deepchem.data.datasets import ImageDataset
import matplotlib.pyplot as plt

import os

path = './data/demo.png'

data = plt.imread(path)
data
# Out:
# array([[[0.23529412, 0.23529412, 0.23529412, 1.        ],
#         [0.23529412, 0.23529412, 0.23529412, 1.        ],
#         [0.23529412, 0.23529412, 0.23529412, 1.        ],
#         ...,
#         [0.23529412, 0.23529412, 0.23529412, 1.        ],
#         [0.23529412, 0.23529412, 0.23529412, 1.        ],
#         [0.23137255, 0.23137255, 0.23137255, 1.        ]],
#
#        [[0.10196079, 0.        , 0.12941177, 1.        ],
#         [0.10588235, 0.        , 0.13725491, 1.        ],
#         [0.10980392, 0.        , 0.13725491, 1.        ],
#         ...,
#         [0.10980392, 0.        , 0.13725491, 1.        ],
#         [0.10588235, 0.        , 0.12941177, 1.        ],
#         [0.07450981, 0.        , 0.09411765, 1.        ]],
#
#        [[0.23529412, 0.00392157, 0.3019608 , 1.        ],
#         [0.24705882, 0.00392157, 0.31764707, 1.        ],
#         [0.2509804 , 0.00392157, 0.31764707, 1.        ],
#         ...,
#         [0.2509804 , 0.00392157, 0.3137255 , 1.        ],
#         [0.24313726, 0.        , 0.3019608 , 1.        ],
#         [0.1764706 , 0.        , 0.21960784, 1.        ]],
#
#        ...,
#
#        [[0.25490198, 0.01960784, 0.33333334, 1.        ],
#         [0.2627451 , 0.02352941, 0.34509805, 1.        ],
#         [0.27058825, 0.02352941, 0.3529412 , 1.        ],
#         ...,
#         [0.27058825, 0.02745098, 0.3529412 , 1.        ],
#         [0.25882354, 0.02352941, 0.34117648, 1.        ],
#         [0.1882353 , 0.01176471, 0.24705882, 1.        ]],
#
#        [[0.24705882, 0.01960784, 0.3254902 , 1.        ],
#         [0.25882354, 0.02745098, 0.34117648, 1.        ],
#         [0.2627451 , 0.02745098, 0.34509805, 1.        ],
#         ...,
#         [0.2627451 , 0.02352941, 0.34509805, 1.        ],
#         [0.25490198, 0.01960784, 0.33333334, 1.        ],
#         [0.18431373, 0.01568628, 0.24313726, 1.        ]],
#
#        [[0.20784314, 0.01960784, 0.27450982, 1.        ],
#         [0.21960784, 0.02352941, 0.28627452, 1.        ],
#         [0.22352941, 0.02745098, 0.29411766, 1.        ],
#         ...,
#         [0.21960784, 0.01568628, 0.2901961 , 1.        ],
#         [0.21176471, 0.01568628, 0.28235295, 1.        ],
#         [0.15686275, 0.01176471, 0.20784314, 1.        ]]], dtype=float32)
